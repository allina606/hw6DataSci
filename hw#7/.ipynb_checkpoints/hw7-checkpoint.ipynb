# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

news = []

val = requests.get('https://openapi.etsy.com/v2/listings/active?api_key={YOUR KEY HERE}').json()


# news.append(requests.get('https://www.cnn.com/').text)
# news.append(requests.get('https://www.nytimes.com/').content)
# news.append(requests.get('https://www.huffpost.com/').content)
# news.append(requests.get('https://www.foxnews.com/').content)
# news.append(requests.get('https://www.washingtonpost.com/').content)
# news.append(requests.get('http://abcnews.go.com').content)
# news.append(requests.get('https://people.com').content)
# news.append(requests.get('https://nbcnews.com').content)
# news.append(requests.get('https://npr.org').content)
# news.append(requests.get('https://news.google.com').content)
# news.append(requests.get('https://npr.org').content)

# # df_list = pd.read_html(news[0])

# # df_list

# soup = BeautifulSoup(news[0], 'html.parser')

# %%
val['results']
# Out:
# [{'listing_id': 843095125,
#   'state': 'active',
#   'user_id': 111682977,
#   'category_id': None,
#   'title': ' custom bitmoji teacher face covering',
#   'description': ' ❌❌⚠️⚠️please message photo like use wanting personalize name, leave notes seller using using black writing double check it’s spelled right ⚠️❌❌ personalize photo you, ready provide proofs purchasing happy send photo it’s finished lightweight extremely soft choice color elastic backing filter included layers fabric fabric inside 100 organic cotton fabric outside 84 polyester 16 spandex comfortable elastic ears pocket filter make warranties, express implied, mask prevents infection transmission viruses diseases medical grade comparable n95 covid19 accept returns cancellations item sales final',
#   'creation_tsz': 1607483440,
#   'ending_tsz': 1617934240,
#   'original_creation_tsz': 1595458956,
#   'last_modified_tsz': 1607483440,
#   'price': '11.00',
#   'currency_code': 'USD',
#   'quantity': 145,
#   'sku': [],
#   'tags': ['face covering',
#    'lightweight mask',
#    'personalized teacher',
#    'personalized mask',
#    'teacher mask',
#    'filter mask',
#    'school mask',
#    'washable mask',
#    'school face covering',
#    'teacher face cover',
#    'teacher face mask',
#    'teacher filter mask'],
#   'materials': ['elastic', 'spandex', 'polyester', 'organic cotton'],
#   'shop_section_id': 29742827,
#   'featured_rank': None,
#   'state_tsz': 1606020796,
#   'url': 'https://www.etsy.com/listing/843095125/custom-bitmoji-teacher-face-covering?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 7585,
#   'num_favorers': 621,
#   'shipping_template_id': 98896513159,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '1',
#   'item_weight_unit': 'oz',
#   'item_length': '10',
#   'item_width': '8',
#   'item_height': '1',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 12112,
#   'taxonomy_path': ['Bath & Beauty',
#    'Personal Care',
#    'Face Masks & Coverings'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 742018299,
#   'state': 'active',
#   'user_id': 83179146,
#   'category_id': None,
#   'title': ' printable farm stickers farm envelope seals',
#   'description': ' description farm stickers envelope seals pdf, doc pdf word doc contain 20 5in stickers physical product shipped, frame props included what’s included you’ll receive file types quot 11 quot sheet 20 stickers, 300 dpi, high resolution, pdf format quot 11 quot sheet 20 stickers, word doc format payment cleared download instant download purchases reviews need download desktop computer able download mobile device printing process final project artwork determined quality printer paper card stock choose mind colors monitor vary slightly appear person display viewing device color calibration device monitor best results, recommend printing using high quality sticker paper note, listing instant download, print mailed print home, print shop, online service following vista print avery weprint recommend avery template 94506 refunds exchanges digital instant download purchase non refundable, way tell printed design questions concerns order, feel free reach anytime terms use purchase strictly non commercial, personal use print design home, business, public place resell, reproduce, distribute electronic means profit way design',
#   'creation_tsz': 1607483434,
#   'ending_tsz': 1617934234,
#   'original_creation_tsz': 1570215246,
#   'last_modified_tsz': 1607483437,
#   'price': '3.00',
#   'currency_code': 'USD',
#   'quantity': 98,
#   'sku': [],
#   'tags': ['Tractor',
#    'Digital',
#    'Download',
#    'envelope seal',
#    'sticker',
#    'cow',
#    'Farm stickers',
#    'Green Tractor',
#    '1 5 sticker',
#    'printable stickers'],
#   'materials': ['Digital', 'Printable', 'PDF', 'WORD'],
#   'shop_section_id': 27079904,
#   'featured_rank': None,
#   'state_tsz': 1606750288,
#   'url': 'https://www.etsy.com/listing/742018299/printable-farm-stickers-farm-envelope?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 42,
#   'num_favorers': 1,
#   'shipping_template_id': None,
#   'processing_min': None,
#   'processing_max': None,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2019',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': True,
#   'file_data': '1 PDF, 1 other file',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1317,
#   'taxonomy_path': ['Paper & Party Supplies',
#    'Paper',
#    'Stickers, Labels & Tags'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 709674747,
#   'state': 'active',
#   'user_id': 51846604,
#   'category_id': None,
#   'title': ' handmade colourful indian embroidery notebooks, green purple yellow blue journals, manifestation diary 39',
#   'description': ' handmade notebooks threr beautiful handmade notebooks recycled materials contains handmade lokta paper colours available, contact photos colour pattern vary slightly size 20cm 15cm',
#   'creation_tsz': 1607483433,
#   'ending_tsz': 1617934233,
#   'original_creation_tsz': 1559038233,
#   'last_modified_tsz': 1607483433,
#   'price': '14.99',
#   'currency_code': 'GBP',
#   'quantity': 5,
#   'sku': [],
#   'tags': ['notebook',
#    'journal',
#    'india',
#    'indian',
#    'om',
#    'shiva',
#    'ganesha',
#    'lakshmi'],
#   'materials': [],
#   'shop_section_id': 31293701,
#   'featured_rank': 3,
#   'state_tsz': 1585740742,
#   'url': 'https://www.etsy.com/listing/709674747/handmade-colourful-indian-embroidery?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 410,
#   'num_favorers': 41,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'collective',
#   'is_supply': 'true',
#   'when_made': '2010_2019',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 326,
#   'taxonomy_path': ['Books, Movies & Music',
#    'Books',
#    'Blank Books',
#    'Journals & Notebooks'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 779878057,
#   'state': 'active',
#   'user_id': 276971223,
#   'category_id': None,
#   'title': ' princess personlized pillowcase, princess gift, girls pillowcase, custom pillowcase, personalized gifts, disney princesses pillowcase',
#   'description': ' ultra soft brushed microfiber allergies free 1800 thread count standard size 20 quot 30 quot pillowcase pillow included max printing size 14 quot 12 quot printed eco friendly water based inks soft smooth touch print felt pillowcase ensuring smooth feel face good nights sleep snuggle bed comfy pillowcase 39 super soft just perfect cozy night’s sleep work provide design proof won 39 print approval sure enter personalization information provided section listing production print pillowcase fresh order just usually able print order business days order printed shipped, usps usually delivers business days returns exchanges kindly note accept returns exchanges personalized custom items nature product custom orders final work orders order receive mind ordering gifts special occasions case larger special orders, immediately order materials needed produce order types orders canceled ex weddings, events, bulk custom orders, special items,',
#   'creation_tsz': 1607483433,
#   'ending_tsz': 1617934233,
#   'original_creation_tsz': 1582039276,
#   'last_modified_tsz': 1607483433,
#   'price': '17.00',
#   'currency_code': 'USD',
#   'quantity': 808,
#   'sku': [],
#   'tags': ['Custom Pillowcase',
#    'Personalized Gifts',
#    'Birthday Gift',
#    'Boy Pillowcase',
#    'Girl Pillowcase',
#    'Pillowcase for Kids',
#    'Character Pillowcase',
#    'Gifts for Kids',
#    'Personal Pillowcase',
#    'Team Logo Gift',
#    'Princess Pillowcase',
#    'Disney Princesses',
#    'Princess Gift'],
#   'materials': [],
#   'shop_section_id': 28161471,
#   'featured_rank': None,
#   'state_tsz': 1607199310,
#   'url': 'https://www.etsy.com/listing/779878057/princess-personlized-pillowcase-princess?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 1504,
#   'num_favorers': 116,
#   'shipping_template_id': 88363222343,
#   'processing_min': 5,
#   'processing_max': 10,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '6',
#   'item_weight_unit': 'oz',
#   'item_length': '9',
#   'item_width': '6',
#   'item_height': '1',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1925,
#   'taxonomy_path': ['Home & Living',
#    'Bedding',
#    'Sheets & Pillowcases',
#    'Pillowcases'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 279460830,
#   'state': 'active',
#   'user_id': 39108619,
#   'category_id': None,
#   'title': ' sterling silver lotus nose stud, tribal nose piercing, tiny indian nose jewelry, small rajasthani nostril screw, flower nose pin ns27',
#   'description': ' beautiful sterling silver lotus nose stud description material sterling silver gauge bar size 20 gauge 8mm total size 9mm 35 39 39 nickel free shipping business days need different gauge create custom order weeks create contact use septum correctly order taking care new septum, 39 important bend sides little possible putting clean septum brass silver oxidize naturally time contact skin wash bit lemon juice vinegar bring metal color, shining bright gold nose studs click link https etsy 33vw1dh nose studs click link https etsy 34im0ii enter shop https www etsy com il en shop ronibiza shop policies returns accepted guarantee refund entirely satisfied order like make return, contact 14 days receiving order thereafter, order shipped customer’s expense jewelry returned unworn original condition packaging ronibiza jewelry right deny return jewelry returned does meet return policy requirements customer responsible return shipping costs items lost damaged carefully inspect pieces leave studio item arrives damaged, reported immediately 24 hours lost damaged packages accept package integrity compromised shows clear signs having opened resealed note authority allowed open package transit local customs packages opened local customs sealed corresponding stamp company shipping orders shipped shipping address supplied etsy order check address correct completing checkout ronibiza jewelry responsible packages shipped incorrect addresses customer’s responsibility ensure shipping information correct prior complete purchase estimated shipping times international mail affected circumstances, 39 solve cases delays end period 30 days shipping date understand package sent, transit times, customs delays, delivery times totally control customs duties fees buyers responsible customs duties fees apply sellers aren 39 responsible delays customs issues postal services feel free contact questions regarding item, processing, shipping, arrival times happy help thank stopping roni',
#   'creation_tsz': 1607483432,
#   'ending_tsz': 1617934232,
#   'original_creation_tsz': 1462716986,
#   'last_modified_tsz': 1607483432,
#   'price': '30.00',
#   'currency_code': 'USD',
#   'quantity': 97,
#   'sku': ['8.10.20*'],
#   'tags': ['silver nose stud',
#    'tribal nose stud',
#    'indian nose stud',
#    'tiny nose piercing',
#    'nostril stud jewelry',
#    'piercing nez',
#    'silver nose screw',
#    'small nose pin',
#    'nasenstecker',
#    'nostril piercing',
#    'flower nose ring',
#    'stud silver nostril',
#    'rajasthani nose ring'],
#   'materials': ['Silver'],
#   'shop_section_id': 28361846,
#   'featured_rank': None,
#   'state_tsz': 1538750314,
#   'url': 'https://www.etsy.com/listing/279460830/sterling-silver-lotus-nose-stud-tribal?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 2305,
#   'num_favorers': 322,
#   'shipping_template_id': 86872882896,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2020_2020',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1189,
#   'taxonomy_path': ['Jewelry', 'Body Jewelry', 'Nose Rings & Studs'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 216477141,
#   'state': 'active',
#   'user_id': 24809798,
#   'category_id': None,
#   'title': ' unicorn 39 red bull',
#   'description': ' quot listen don 39 listen me, listen brave passed roads long ago, red bull ran close covered footprints listen listen, listen quickly quot butterfly brave, tame smaller version peter beagle 39 red bull mythfit polyester fleece button eyes sand feet help stand nicely feather boa fiery mane tail adjustable approximately 14 inches tail tip horn tip inches tall',
#   'creation_tsz': 1607483432,
#   'ending_tsz': 1617934232,
#   'original_creation_tsz': 1419807060,
#   'last_modified_tsz': 1607483432,
#   'price': '25.00',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['unicorn',
#    'last unicorn',
#    'peter beagle',
#    'book',
#    'novel',
#    'bull',
#    'animal',
#    'toy',
#    'horn',
#    'red bull'],
#   'materials': ['feather', 'fleece', 'rice'],
#   'shop_section_id': 12170342,
#   'featured_rank': None,
#   'state_tsz': 1606949825,
#   'url': 'https://www.etsy.com/listing/216477141/last-unicorns-the-red-bull?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 1170,
#   'num_favorers': 253,
#   'shipping_template_id': 153503210,
#   'processing_min': 5,
#   'processing_max': 10,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': None,
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': None,
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1580,
#   'taxonomy_path': ['Toys & Games', 'Toys'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 237902689,
#   'state': 'active',
#   'user_id': 16556526,
#   'category_id': None,
#   'title': ' i05 135 meal icon stickers',
#   'description': ' meal planning stickers printed matte, white sticker paper die cut stickers non removable sheet perfect use planners erin condren, plum paper, filofax, kikki k, item order follow owlplanwithyou instagram updates sales artwork nedtidesigns',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1435018817,
#   'last_modified_tsz': 1607483431,
#   'price': '3.35',
#   'currency_code': 'USD',
#   'quantity': 6,
#   'sku': [],
#   'tags': ['erin condren',
#    'life planner',
#    'planner',
#    'stickers',
#    'food',
#    'meal',
#    'silverware',
#    'meal planning',
#    'kikki k',
#    'limelife',
#    'filofax'],
#   'materials': [],
#   'shop_section_id': 21349142,
#   'featured_rank': None,
#   'state_tsz': 1590805653,
#   'url': 'https://www.etsy.com/listing/237902689/i05-135-meal-icon-stickers?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 381,
#   'num_favorers': 34,
#   'shipping_template_id': 13794330703,
#   'processing_min': 5,
#   'processing_max': 7,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '0.1',
#   'item_weight_unit': 'oz',
#   'item_length': '4',
#   'item_width': '4',
#   'item_height': '0.01',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 6614,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Party & Gifting',
#    'Labels, Stickers & Tags',
#    'Stickers'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 726516845,
#   'state': 'active',
#   'user_id': 9520630,
#   'category_id': None,
#   'title': ' fmp 11 2pcs mink fur ball stud earring loop, 92 silver post, 18 colors blue',
#   'description': ' plating gold 16k electric gold plating silver original rhodium plating matte gold electric gold plating matte silver electric silver platingnumber 14 shape mink fur ball stud earring loop measuring approx 30 mm 30mm quot quantity pieces pair material genuine real mink fur, 8mm diameter raw brass unplated 925 sterling silver post 92 silver ear studs stoppers included 18 colors black, royal blue, brown, dark pink, yellow, purple lt pink, burgundy, fuchsia, navy, beige, violet sky blue, charcoal, gray, white, dark green, red wholesale 10pcs discount 30pcs 10 discount 50pcs 15 discount 100pcs 20 discount 300pcs 25 discount choose colors, quantities write buyer 39 memo send mail',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1564968968,
#   'last_modified_tsz': 1607483431,
#   'price': '3.60',
#   'currency_code': 'USD',
#   'quantity': 48,
#   'sku': [],
#   'tags': ['wholesale',
#    'supply',
#    'fashion jewellery',
#    'handmade jewelry',
#    'boho earrings',
#    'making errings',
#    'wedding jewelry',
#    'genuine fur',
#    'mink ball',
#    'pompom',
#    'mini ball',
#    'silver post'],
#   'materials': [],
#   'shop_section_id': 23458345,
#   'featured_rank': None,
#   'state_tsz': 1603766039,
#   'url': 'https://www.etsy.com/listing/726516845/fmp-11-2pcs-mink-fur-ball-stud-earring?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 14,
#   'num_favorers': 2,
#   'shipping_template_id': 57260412590,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'collective',
#   'is_supply': 'true',
#   'when_made': '2010_2019',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 6239,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Beads, Gems & Cabochons',
#    'Charms & Pendants'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 837473056,
#   'state': 'active',
#   'user_id': 338923011,
#   'category_id': None,
#   'title': ' sweet dreams canvas calligraphy painting, bedroom kids room nursery wall art sign decor, night sky moon stars',
#   'description': ' acrylic canvas painting words quot sweet dreams quot written calligraphy cursive beautiful bedroom, kid 39 room, nursery choose canvas sizes 10 11 14 inches pictures quot 10 quot special requests, contact happy custom orders different quotes, fonts, colors',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1596852429,
#   'last_modified_tsz': 1607483431,
#   'price': '17.00',
#   'currency_code': 'USD',
#   'quantity': 20,
#   'sku': [],
#   'tags': ['Sweet dreams',
#    'Painting',
#    'Wall art',
#    'Wall decor',
#    'Canvas',
#    'Kids room',
#    'Nursery',
#    'Goodnight',
#    'Bedroom',
#    'Stars',
#    'Calligraphy',
#    'Night',
#    'Sky'],
#   'materials': ['Acrylic paint', 'Canvas'],
#   'shop_section_id': 29869500,
#   'featured_rank': None,
#   'state_tsz': 1602812990,
#   'url': 'https://www.etsy.com/listing/837473056/sweet-dreams-canvas-calligraphy-painting?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 14,
#   'num_favorers': 1,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '7',
#   'item_weight_unit': 'oz',
#   'item_length': '14',
#   'item_width': '11',
#   'item_height': '0.75',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1027,
#   'taxonomy_path': ['Home & Living', 'Home Décor', 'Wall Décor'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 879842964,
#   'state': 'active',
#   'user_id': 364458099,
#   'category_id': None,
#   'title': ' tyler, creator flower boy demo tapes personalized spotify apple music plexiglass poster table stand choose song',
#   'description': ' choose interface size wish order spotify apple size a5 size 14 8cm 21cm inch a4 size 21cm 29 7cm 11 inch choose song album want displayed acrylic decor poster printed transparent 1,5mm plexiglass decors delivered small stands easily use table stand unique gift idea occasion responsibility safe delivery item feel free contact questions',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1603789679,
#   'last_modified_tsz': 1607483431,
#   'price': '14.99',
#   'currency_code': 'USD',
#   'quantity': 41,
#   'sku': [],
#   'tags': ['Acrylic',
#    'poster',
#    'stand',
#    'gift',
#    'birthday',
#    'Christams',
#    'modern',
#    'transparent',
#    'apple',
#    'spotify',
#    'albums',
#    'Tyler The Creator',
#    'Flower Boy'],
#   'materials': [],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1606890305,
#   'url': 'https://www.etsy.com/listing/879842964/tyler-the-creator-flower-boy-demo-tapes?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 516,
#   'num_favorers': 72,
#   'shipping_template_id': None,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1027,
#   'taxonomy_path': ['Home & Living', 'Home Décor', 'Wall Décor'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 745815102,
#   'state': 'active',
#   'user_id': 71353235,
#   'category_id': None,
#   'title': ' soft blue medium rounded bowl',
#   'description': ' pretty, soft blue glaze brown stoneware, rounded shape bowl perfect size uses holding 12 oz, 39 great salad, yogurt, cereal, ice cream, snacks, chili favorite glaze combinations, favorite multi tasking vessel dimensions bowl quot high circumference quot holds 12 oz sierra pottery piece kind, attentive craftsmanship potter eileen sierra eastern coast sunshine state florida vessels hand thrown hand built using high quality stoneware oven microwave safe, glazed food safe functional glazes dishwasher safe, recommend hand washing damaged handled gently, just like ceramic pieces durable, functional stoneware wheel thrown hand built palm coast, fl, usa oven, microwave dishwasher safe recommend hand washing protect ceramic surface hand painted dipped, lead free, food safe glazes pieces ready shipped sent business days order placed joy finding homes pieces enjoyed family friends, pleasing eye functional',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1575600238,
#   'last_modified_tsz': 1607483431,
#   'price': '25.00',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['multi-function',
#    'rounded bowl',
#    'blue glaze',
#    'ceramic',
#    'stoneware',
#    'oven safe',
#    'microwave safe',
#    'dishwasher safe',
#    'food safe',
#    'wheel thrown',
#    'hand made',
#    'salad bowl',
#    'soup bowl'],
#   'materials': ['Ceramic'],
#   'shop_section_id': 27559225,
#   'featured_rank': None,
#   'state_tsz': 1605064317,
#   'url': 'https://www.etsy.com/listing/745815102/soft-blue-medium-rounded-bowl?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 83,
#   'num_favorers': 1,
#   'shipping_template_id': 80387033374,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2019',
#   'item_weight': '29',
#   'item_weight_unit': 'oz',
#   'item_length': '8',
#   'item_width': '8',
#   'item_height': '8',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1044,
#   'taxonomy_path': ['Home & Living',
#    'Kitchen & Dining',
#    'Dining & Serving',
#    'Bowls'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 906995456,
#   'state': 'active',
#   'user_id': 281963997,
#   'category_id': None,
#   'title': ' antler bottle opener',
#   'description': ' perfect gift outdoors person likes kick cold beverage handle red stag antler, new zealand relative elk opener chrome comfortable grip flare base ends sealed materials legally harvested repurposed',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1607483431,
#   'last_modified_tsz': 1607483432,
#   'price': '45.00',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['handmade',
#    'exotic',
#    'unique',
#    'bottle',
#    'craft',
#    'artisan',
#    'special',
#    'gift',
#    'oneofakind',
#    'antler',
#    'bottle opener'],
#   'materials': ['Metal'],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1607483431,
#   'url': 'https://www.etsy.com/listing/906995456/antler-bottle-opener?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 0,
#   'num_favorers': 0,
#   'shipping_template_id': 106944604451,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2020_2020',
#   'item_weight': None,
#   'item_weight_unit': None,
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': None,
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': True,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1057,
#   'taxonomy_path': ['Home & Living',
#    'Kitchen & Dining',
#    'Drink & Barware',
#    'Barware',
#    'Bottle Openers'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 250435000,
#   'state': 'active',
#   'user_id': 25836703,
#   'category_id': None,
#   'title': ' buffalo bone breastplate, ceremonial regalia, tone bone leather necklace, native inspired, pow wow jewelry',
#   'description': ' half size breastplate choker buffalo bone hairpipe turquoise beads pow wow ceremonial jewelry native american healing shaman inspired item ships using usps priority mail including insurance breastplate size 26 row choker breastplate quot high quot wide choker necklace 10 quot wide plus quot adjustable leather cords tie leather cord fringe quot long thanks visiting lennie 39 bead drawer click similar style ceremonial healing jewelry https www etsy com shop lenniesbeaddrawer search search query choker order date desc view type gallery ref shop search click return bone pendant choker section https www etsy com shop lenniesbeaddrawer section id 12381210 ref shopsection leftnav click return storefront https www etsy com shop lenniesbeaddrawer ref shopsection shophome leftnav',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1443817689,
#   'last_modified_tsz': 1607483431,
#   'price': '28.00',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['Native Inspired',
#    'Pow Wow Jewelry',
#    'Ceremonial Regalia',
#    'regalia',
#    'brown Choker',
#    'Brown and Cream',
#    'Two Tone necklace',
#    'Bone and Leather',
#    'bone Necklace',
#    'leather necklace',
#    'bone breastplate',
#    'Breastplate',
#    'buffalo bone'],
#   'materials': ['buffalo bone hairpipe', 'leather', 'bone spacer beads'],
#   'shop_section_id': 12381210,
#   'featured_rank': None,
#   'state_tsz': 1606152168,
#   'url': 'https://www.etsy.com/listing/250435000/buffalo-bone-breastplate-ceremonial?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 4184,
#   'num_favorers': 231,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2019',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1223,
#   'taxonomy_path': ['Jewelry', 'Necklaces', 'Chokers'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 206545548,
#   'state': 'active',
#   'user_id': 24809798,
#   'category_id': None,
#   'title': ' leonardo teenage mutant ninja turtles mini tmnt plush plushie toy',
#   'description': ' leonardo, leads, fluffy tiny teenage mutant ninja turtles embroidered face squishy shell non smoking, pet friendly home soft fleece, filled poly fiberfill rice weights legs wobbling',
#   'creation_tsz': 1607483431,
#   'ending_tsz': 1617934231,
#   'original_creation_tsz': 1412885029,
#   'last_modified_tsz': 1607483431,
#   'price': '10.00',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['tmnt',
#    'mutant turtles',
#    'ninja turtles',
#    'cartoon',
#    '80s',
#    'plush',
#    'raphael',
#    'leonardo',
#    'donatello',
#    'michelangelo',
#    'michaelangelo',
#    'pizza'],
#   'materials': ['fleece'],
#   'shop_section_id': 12170342,
#   'featured_rank': None,
#   'state_tsz': 1606949825,
#   'url': 'https://www.etsy.com/listing/206545548/leonardo-teenage-mutant-ninja-turtles?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 267,
#   'num_favorers': 59,
#   'shipping_template_id': 153503210,
#   'processing_min': 5,
#   'processing_max': 10,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': None,
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': None,
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1580,
#   'taxonomy_path': ['Toys & Games', 'Toys'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 837471074,
#   'state': 'active',
#   'user_id': 342398563,
#   'category_id': None,
#   'title': ' pc, rose wood applique onlay, shabby chic, wood carved home embellishments, furniture carving appliques suppliesrosette applique shabby',
#   'description': ' hello set pc flower rose wood applique supplies products unique designs decorate furniture, walls ceilings lightweight easily stick flat surface want i̇t better paint wax using cracks occur dry state good physical properties thanks stopping',
#   'creation_tsz': 1607483430,
#   'ending_tsz': 1617934230,
#   'original_creation_tsz': 1596852076,
#   'last_modified_tsz': 1607483430,
#   'price': '21.00',
#   'currency_code': 'USD',
#   'quantity': 100,
#   'sku': [],
#   'tags': ['wood wall decor',
#    'furniture onlay',
#    'no seal applique',
#    'wood applique',
#    'wood embellisment',
#    'craft supplies',
#    'furnitare tools',
#    'repaint wood decor',
#    'home improvement',
#    'home hardware',
#    'solid wood hardware',
#    'flower wood'],
#   'materials': ['solid wood', 'ahşap'],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1597687377,
#   'url': 'https://www.etsy.com/listing/837471074/6-pc-rose-wood-applique-onlay-shabby?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 17,
#   'num_favorers': 2,
#   'shipping_template_id': None,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'collective',
#   'is_supply': 'true',
#   'when_made': '2020_2020',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 994,
#   'taxonomy_path': ['Home & Living',
#    'Furniture',
#    'Living Room Furniture',
#    'Console Tables & Cabinets'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 204800040,
#   'state': 'active',
#   'user_id': 45850674,
#   'category_id': None,
#   'title': ' mailing upgrade does shorten production turnaround time, shorten mailing transit time usps',
#   'description': ' buy item purchase items shop https www etsy com shop centimegift production time remains just upgrade mail type domestic shipping priority upgrade costs 4, shipping upgrade usps priority express upgrade costs 20, shipping upgrade ups days international shipping international express upgrade costs 35, shipping upgrade dhl international express',
#   'creation_tsz': 1607483430,
#   'ending_tsz': 1617934230,
#   'original_creation_tsz': 1411647057,
#   'last_modified_tsz': 1607483430,
#   'price': '4.00',
#   'currency_code': 'USD',
#   'quantity': 725,
#   'sku': [],
#   'tags': [],
#   'materials': [],
#   'shop_section_id': 18842674,
#   'featured_rank': None,
#   'state_tsz': 1607455096,
#   'url': 'https://www.etsy.com/listing/204800040/mailing-upgrade-does-not-shorten?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 2749,
#   'num_favorers': 20,
#   'shipping_template_id': 63334548720,
#   'processing_min': 10,
#   'processing_max': 15,
#   'who_made': 'collective',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1179,
#   'taxonomy_path': ['Jewelry'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 760532513,
#   'state': 'active',
#   'user_id': 198480421,
#   'category_id': None,
#   'title': ' 40 pcs nemesia strumosa danish flag flower seeds nemesia strumosa suttonii triumph national ensign fl420',
#   'description': ' 40 pcs nemesia strumosa danish flag flower seeds nemesia strumosa suttonii triumph national ensign fl420 nemesia strumosa suttonii triumph national ensign charming cool season annual pretty little snapdragon shape flowers fragrant bloom wide range colours nemesia strumosa compact branched plant flowers early continues summer autumn perfect plant carpet bedding prefers moist drained soil needs sun day danish flag strain striking pansy like, deep flowers, compact habit ideal patio container compact bedding plant abundance showy flowers unquestionably powerfully impulsive flower colours recently introduction horticultural world petals blooded, strong vibrant red, clear contrast lower petals creamy whiteness making nemesia danish flag beautiful variety grow nemesia flower seed sow nemesia seeds indoors weeks frost sow flower seed surface starter compost gently firm compost, lightly cover soil damp wet exclude light nemesia seedlings large handle, transplant inch pots grow cooler conditions gradually acclimatize young nemesia seedlings outdoor conditions seedlings grow, pinch times encourage compact growth transplant outdoors risk frost passed, inches apart directly sow nemesia seeds outdoors prepared beds danger frost passed inches apart season annual usda zones height 10 inches bloom season late spring fall bloom color red environment sun soil type moist, drained, ph temperature 65 72 18 22 average germ time 14 days light required yes depth press seeds soil cover lightly sowing rate seeds plant moisture seeds moist germination plant spacing inches',
#   'creation_tsz': 1607483430,
#   'ending_tsz': 1617934230,
#   'original_creation_tsz': 1575861255,
#   'last_modified_tsz': 1607483430,
#   'price': '3.97',
#   'currency_code': 'CAD',
#   'quantity': 5,
#   'sku': [],
#   'tags': ['exotic flower',
#    'Nemesia Blue Gem',
#    'Nemesia Strumosa',
#    'Nana Compacta',
#    'Nemesia Carnival Mix',
#    'Strumosa',
#    'Nemesia',
#    'Nemesia Red ensign',
#    'Nemesia Danish Flag',
#    'Suttonii Triumph',
#    'National Ensign',
#    'Danish Flag Flower'],
#   'materials': [],
#   'shop_section_id': 25426166,
#   'featured_rank': None,
#   'state_tsz': 1586711504,
#   'url': 'https://www.etsy.com/listing/760532513/40-pcs-nemesia-strumosa-danish-flag?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 22,
#   'num_favorers': 1,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 2,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2019',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6619,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Floral & Garden Supplies',
#    'Floral',
#    'Flowers'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 665234777,
#   'state': 'active',
#   'user_id': 9552785,
#   'category_id': None,
#   'title': ' golden ratio earrings, fibonacci sequence, golden mean, divine proportion, phi',
#   'description': ' golden ratio elegant round earrings dark wood symbol artists, architects, mathematicians naturalists, golden ratio depicts perfectly symmetrical relationship proportions appears patterns nature, including spiral arrangement plants shells, aesthetically pleasing basis design art architecture earring set finely hand painted gold enamel, 3mm wenge wood, non tarnish brass ear wires designs begin original hand drawing, cut laser cutter variety quality woods pieces finished cleaning, sanding necessary, sealed non toxic wood sealer',
#   'creation_tsz': 1607483429,
#   'ending_tsz': 1617934229,
#   'original_creation_tsz': 1544147786,
#   'last_modified_tsz': 1607483429,
#   'price': '21.95',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': ['PKB_e005'],
#   'tags': ['Earrings',
#    'Natural Wood jewelry',
#    'Artistic',
#    'Laser Cut Jewelry',
#    'Round Wood Earrings',
#    'Mathematical Design',
#    'Laser Cut Wood',
#    'Golden Section',
#    'Golden Ratio',
#    'Fibonacci Sequence',
#    'Golden Ratio jewelry',
#    'Elegant Design',
#    'Wood Earrings'],
#   'materials': ['Wood', 'Brass'],
#   'shop_section_id': 25288480,
#   'featured_rank': None,
#   'state_tsz': 1607445209,
#   'url': 'https://www.etsy.com/listing/665234777/golden-ratio-earrings-fibonacci-sequence?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 179,
#   'num_favorers': 48,
#   'shipping_template_id': 64737905576,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '6',
#   'item_weight_unit': 'oz',
#   'item_length': '8',
#   'item_width': '4',
#   'item_height': '0.5',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1208,
#   'taxonomy_path': ['Jewelry', 'Earrings', 'Dangle & Drop Earrings'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 798485318,
#   'state': 'active',
#   'user_id': 194232080,
#   'category_id': None,
#   'title': ' incense stick cone mango wood hole disc, eco friendly incense holder, incense burner ash catcher 20 free vegan friendly incense sticks',
#   'description': ' incense stick cone mango wood hole disc, natural, eco friendly bamboo incense holder incense burner ash catcher 20 free patchouli vegan friendly incense sticks details choose hole disk incense holder design comes 20 free incense sticks pick fragrance drop burn time incense stick hour double time branded incense including eco friendly mango wood holder approx diameter 9cm thickness 1cm holder hold incense sticks incense cone including vegan friendly incense sticks approx length 250mm holder incense sticks gift wrapped natural, eco friendly packaging shop announcement getting orders time aware likely delays estimated delivery times ongoing problems brought coronavirus pandemic thanks custom stay safe packaging bubble wrap envelopes plant based contain plastic free gifts orders £35gbp including shipping',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1590006413,
#   'last_modified_tsz': 1607483428,
#   'price': '3.99',
#   'currency_code': 'GBP',
#   'quantity': 7,
#   'sku': [],
#   'tags': ['Incense',
#    'Incense Holder',
#    'Ash Catcher',
#    'Incense Burner',
#    'Holder',
#    'Cheap Incense',
#    'Vegan',
#    'Ecofriendly',
#    'Incense Stick Holder',
#    'Burner',
#    'Joss Stick',
#    'Natural',
#    'Elephant'],
#   'materials': ['Vegan Incense',
#    'Eco Friendly Packaging',
#    'Mango Wood Holder',
#    'Round Disk Incense Holder',
#    '4 Stick Burner',
#    'Incense Sticks',
#    'Incense Cones'],
#   'shop_section_id': 25473792,
#   'featured_rank': None,
#   'state_tsz': 1601036461,
#   'url': 'https://www.etsy.com/listing/798485318/incense-stick-cone-mango-wood-4-hole?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 677,
#   'num_favorers': 128,
#   'shipping_template_id': 89083907509,
#   'processing_min': 4,
#   'processing_max': 5,
#   'who_made': 'collective',
#   'is_supply': 'false',
#   'when_made': '2020_2020',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1144,
#   'taxonomy_path': ['Home & Living',
#    'Spirituality & Religion',
#    'Religious Candles & Incense',
#    'Incense'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 694196465,
#   'state': 'active',
#   'user_id': 38841407,
#   'category_id': None,
#   'title': ' love daddy, stamped vintage spoon, fathers day gift, gift',
#   'description': ' hand stamped vintage silver plate spoon special day stamped quot love daddy quot great gift wonderful daddy vintage piece lovingly hand stamped letter time create unique treasure that, impossible guarantee letters perfectly aligned believe lends charm piece tool markings silver plate, shown photos wonderful vintage pieces years prior use, imperfections expected treasured signs wear include minor plate loss, scratches, pitting hand washing highly recommended help preserve darkening letters darkening wear time, stamping impression remain',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1553738156,
#   'last_modified_tsz': 1607483428,
#   'price': '19.00',
#   'currency_code': 'USD',
#   'quantity': 36,
#   'sku': [],
#   'tags': ['stamped spoon',
#    'hand stamped spoon',
#    'fathers day gift',
#    'silver plate spoon',
#    'we love you daddy',
#    'Love daddy',
#    'daddy gift',
#    'daddy spoon',
#    'love dad',
#    'love you daddy',
#    'gifts for dad',
#    'coffee lover',
#    'I love daddy'],
#   'materials': ['Metal'],
#   'shop_section_id': 14395923,
#   'featured_rank': None,
#   'state_tsz': 1601342942,
#   'url': 'https://www.etsy.com/listing/694196465/i-love-you-daddy-stamped-vintage-spoon?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 38,
#   'num_favorers': 1,
#   'shipping_template_id': 12797083118,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1052,
#   'taxonomy_path': ['Home & Living',
#    'Kitchen & Dining',
#    'Dining & Serving',
#    'Serving Utensils'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 742342789,
#   'state': 'active',
#   'user_id': 173923482,
#   'category_id': None,
#   'title': ' couples shirts like butt like beard shirts halloween couples matching funny costume tees',
#   'description': ' cool fun couples shirt combo enjoy wear halloween, work parties social gathering great halloween valentine 39 day sure choose correct design size drop options shirts 100 preshrunk cotton sizing chart listed jpeg picture item listing shirts unisex men 39 sizing care instructions best practice machine wash cold, inside hang dry',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1570328394,
#   'last_modified_tsz': 1607483428,
#   'price': '15.98',
#   'currency_code': 'USD',
#   'quantity': 77,
#   'sku': [],
#   'tags': ['couples matching',
#    'couples costume',
#    'halloween',
#    'valentines day',
#    'trick or treat'],
#   'materials': [],
#   'shop_section_id': 27231235,
#   'featured_rank': None,
#   'state_tsz': 1602783607,
#   'url': 'https://www.etsy.com/listing/742342789/couples-t-shirts-i-like-her-butt-i-like?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 1771,
#   'num_favorers': 229,
#   'shipping_template_id': 62685422789,
#   'processing_min': 3,
#   'processing_max': 4,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 482,
#   'taxonomy_path': ['Clothing',
#    'Unisex Adult Clothing',
#    'Tops & Tees',
#    'T-shirts'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 814433323,
#   'state': 'active',
#   'user_id': 235616991,
#   'category_id': None,
#   'title': ' agust inspired gouache bts fanart bangtan sonyeondan 방탄소년단',
#   'description': ' print gouache painting newly release music video agust d2 min yoongi known suga print original artwork printed 300gsm paper, glossy finish inches 10x15cm inches 13x18cm select size drop menu',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1590373048,
#   'last_modified_tsz': 1607483428,
#   'price': '4.50',
#   'currency_code': 'GBP',
#   'quantity': 67,
#   'sku': [],
#   'tags': ['min yoongi',
#    'suga',
#    'AGUST D2',
#    'agust d',
#    'Fanart',
#    'Bt21',
#    'BTS digital print',
#    'BTS print',
#    'BTS',
#    'BTS fan art',
#    'Bangtan sonyeondan'],
#   'materials': [],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1598964148,
#   'url': 'https://www.etsy.com/listing/814433323/agust-d-d-2-inspired-gouache-bts-fanart?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 876,
#   'num_favorers': 284,
#   'shipping_template_id': 77226926139,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 125,
#   'taxonomy_path': ['Art & Collectibles', 'Prints', 'Music & Movie Posters'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 855049846,
#   'state': 'active',
#   'user_id': 361778267,
#   'category_id': None,
#   'title': ' atv shirt mud shirt road shirt 4x4 shirt southern girl mudding shirt country shirt cute country shirt lifted truck',
#   'description': ' 🌟🌟🌟important🌟🌟🌟 final day xmas orders december 🌟🌟🌟 pandemic intensity christmas, delays shipment orders 🌟🌟🌟 adult unisex tee retail fit 100 soft cotton unisex heavy tee classic fit 100 cotton check photos details processing time days holidays expect delays orders slightly higher usual, best order soon possible sizing unisex, runs true size graphic size chart recommend sizing feminine, fitted look material high quality adult unisex tee bella canvas unisex heavy tee gildan cotton shirts soft comfortable shipping time class shipping business days priority shipping includes tracking business days returns refund items order try best send products best quality problems caused us,we refund exchange 🌟🌟🌟if problem product, contact 🌟🌟🌟 🌟🌟🌟if questions request 🌟🌟🌟 thank',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1599781078,
#   'last_modified_tsz': 1607483428,
#   'price': '89.59',
#   'currency_code': 'TRY',
#   'quantity': 446,
#   'sku': [],
#   'tags': ['ATV Shirt',
#    'Mud Shirt',
#    'Off Road Shirt',
#    '4x4 Shirt',
#    'Southern Girl',
#    'Mudding Shirt',
#    'Country Shirt',
#    'Cute Country Shirt',
#    'Lifted Truck',
#    'cowgirl shirt',
#    'cute country',
#    'Mud Racing',
#    'Mud Tee'],
#   'materials': ['Cotton'],
#   'shop_section_id': 30498747,
#   'featured_rank': None,
#   'state_tsz': 1599784413,
#   'url': 'https://www.etsy.com/listing/855049846/atv-shirt-mud-shirt-off-road-shirt-4x4?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 46,
#   'num_favorers': 6,
#   'shipping_template_id': 108846233091,
#   'processing_min': 1,
#   'processing_max': 9,
#   'who_made': 'i_did',
#   'is_supply': 'true',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 11165,
#   'taxonomy_path': ['Clothing',
#    'Unisex Adult Clothing',
#    'Tops & Tees',
#    'T-shirts',
#    'Graphic Tees'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 687227351,
#   'state': 'active',
#   'user_id': 199892472,
#   'category_id': None,
#   'title': ' create air freshener aroma bead car freshie',
#   'description': ' create freshie shapes scents offer select shape fragrance want match needs air fresheners freshies highest quality aroma beads, oils fragrances allow days order ship include weekends holidays place freshie car, closet, drawer, office locker small space smelling fresh amazing freshies normally weeks fragrances longer time frame freshies aromatic warmer environments adding new scents note air fresheners handmade items, slight visual effect place freshie dashboard vehicle set plastic wood surfaces meant hang make sure like wick aroma facebook facebook com nowickaroma daily deals choose shape texas, cactus, flamingo, llama, unicorn head, tee pee, lips, mason jar, guitar, pineapple, heart, longhorn, cross, angel, cancer ribbon, mermaid tail, boot, palm tree, sunflower pina colada right choose scent scent name, scent color description thousand wishes bbw type light pink replica bath body works scent soft blend sparkling champagne, peonies almond crème bird paradise medium pink replica popular circle candle fragrance sweet tropical berries mingle aroma rich lotus blossoms vanilla orchid description scent definitely smells like circle candle car wash cherry red intense scent black cherries smells just like detailed car description scent smells like cherry strawberry leather cherry leather brown red sweet tart leathery scent blend leather intense scent black cherry description scent leather cherry mixed creed aventus replica highly luxurious cologne creed aventus base notes pineapple, bergamot, black currant apple, middle notes patchouli, dry birch, rose moroccan jasmine notes vanilla, musk oak moss description smells good greatly manly scent fierce brown replica abercrombie fierce notes fir, lemon orange rosemary, jasmine lily valley mid tones finishes musk, vetiver rosewood hawaiian flower light purple tropical blend fruity notes orange, pineapple, peach strawberry combined floral mixture jasmine lavender description scent smells like glade plug hawaiian breeze leather brown leathery bouquet smells like inside saddle shop love spell pink interpretation fragrance victoria’s secrets fresh fruity citrus fragrance notes grapefruit, apple, strawberries clementine’s middle note peach, black currant rose petals sweet white musky base note mahogany teakwood brown masculine luxurious scent fine woods blended light scents lavender geranium notes description scent smells just like bw candle monkey farts light orange unique blend bananas, fresh grapefruit, strawberries, kiwi, bubble gum touch vanilla pina colada yellow smells just like drink strawberry light pink sweet scent strawberry strawberry leather brown pink strawberry leather scent blend leather intense scent strawberry description scent leather strawberry mixed cherry leather sun tan lotion dark blue tropical twist coconut milk cool vanilla it’s perfect summer escape sweet saddle shop brown pink sweet leathery scent blend leather warmth vanilla musk wood description scent sweet leather mix leather bird paradise',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1551486610,
#   'last_modified_tsz': 1607483428,
#   'price': '7.00',
#   'currency_code': 'USD',
#   'quantity': 947,
#   'sku': [],
#   'tags': ['air freshener',
#    'freshie',
#    'Car candle',
#    'aroma bead',
#    'aroma bead freshie',
#    'car freshener',
#    'car air freshener',
#    'create your own',
#    'aroma bead freshener',
#    'gifts for her',
#    'gifts for him',
#    'gift',
#    'stocking stuffer'],
#   'materials': ['aroma beads', 'fragrance oil'],
#   'shop_section_id': None,
#   'featured_rank': 1,
#   'state_tsz': 1599928915,
#   'url': 'https://www.etsy.com/listing/687227351/create-your-own-air-freshener-aroma-bead?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 20718,
#   'num_favorers': 404,
#   'shipping_template_id': None,
#   'processing_min': 5,
#   'processing_max': 7,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '3',
#   'item_weight_unit': 'oz',
#   'item_length': '9',
#   'item_width': '6',
#   'item_height': '1',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 920,
#   'taxonomy_path': ['Home & Living', 'Cleaning Supplies', 'Air Fresheners'],
#   'used_manufacturer': False,
#   'is_vintage': False},
#  {'listing_id': 815108008,
#   'state': 'active',
#   'user_id': 281169411,
#   'category_id': None,
#   'title': ' jigsaw puzzle personalized baby gift toddler 1st birthday gift baby boy wooden puzzle dino toy baby girl gift infant',
#   'description': ' jigsaw puzzle personalized baby gift toddler 1st birthday gift baby boy wooden puzzle dino toy baby girl gift infant unique wooden toys little ones looking baby gifts amazing nursery decor puzzle meaningful personalized wooden toy helps develop motor skills baby serves wonderful decoration check store designs message custom ones great gift idea 1st birthday 2nd, 3rd christmas, thanksgiving, baby shower occasion baby girl, baby boy, toddlers kids notice don 39 mention design notes order dinosaurs design main photo subscribe newsletter special discounts, news offers http eepurl com g8gki5 add stands puzzle display decoration https www etsy com listing 782856542 acrylic stands puzzle ref listing published alert choose design listing multiple designs, check picture choose design want puzzle also, provide design 39 number quot add personalization quot box printed wood designs shop technology organic materials safe, non toxic paints used birch plywood board 31 inches 8mm letter 15 inches 4mm 36 inches tall 6cm gift packaging available checkout customize message request customization step choose correct letters baby 39 ex step decide want pegs text ex pegs, text back, pegs text step choose color scheme number option ex step provide design chose, text chose option quot add personalization quot box business days needed prepare send order custom designs little longer shipping time calculated package dispatched shipped date standard delivery rates usa 10 business days united kingdom 14 business days europe 16 business days canada business days countries business days',
#   'creation_tsz': 1607483428,
#   'ending_tsz': 1617934228,
#   'original_creation_tsz': 1592991650,
#   'last_modified_tsz': 1607483428,
#   'price': '19.75',
#   'currency_code': 'USD',
#   'quantity': 858,
#   'sku': ['ЛИСТИНГ С ВЫБОРОМ ДИЗАЙНА'],
#   'tags': ['Jigsaw Puzzle',
#    'Baby puzzle',
#    'Personalized Gift',
#    'Personalize Baby',
#    'Baby Gift',
#    'Gift for Toddler',
#    'Baby Boy',
#    '1st Birthday Gift',
#    'Gift for Baby',
#    'Wooden Puzzle',
#    'Dino Toy',
#    'Baby Girl',
#    'Gift for Infant'],
#   'materials': ['wood', 'organic'],
#   'shop_section_id': 28243028,
#   'featured_rank': None,
#   'state_tsz': 1606832624,
#   'url': 'https://www.etsy.com/listing/815108008/jigsaw-puzzle-personalized-baby-gift-for?utm_source=gettingproductlistin&utm_medium=api&utm_campaign=api',
#   'views': 3335,
#   'num_favorers': 275,
#   'shipping_template_id': 86400462898,
#   'processing_min': 1,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 2353,
#   'taxonomy_path': ['Toys & Games',
#    'Games & Puzzles',
#    'Puzzles',
#    'Jigsaw Puzzles'],
#   'used_manufacturer': False,
#   'is_vintage': False}]

# %%
stop_words = ["a", "about", "above", "above", "across", "after", "afterwards", "again", "against", "all", "almost", "alone", "along", "already", "also","although","always","am","among", "amongst", "amoungst", "amount",  "an", "and", "another", "any","anyhow","anyone","anything","anyway", "anywhere", "are", "around", "as",  "at", "back","be","became", "because","become","becomes", "becoming", "been", "before", "beforehand", "behind", "being", "below", "beside", "besides", "between", "beyond", "bill", "both", "bottom","but", "by", "call", "can", "cannot", "cant", "co", "con", "could", "couldnt", "cry", "de", "describe", "detail", "do", "done", "down", "due", "during", "each", "eg", "eight", "either", "eleven","else", "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone", "everything", "everywhere", "except", "few", "fifteen", "fify", "fill", "find", "fire", "first", "five", "for", "former", "formerly", "forty", "found", "four", "from", "front", "full", "further", "get", "give", "go", "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter", "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his", "how", "however", "hundred", "i", "ie", "if", "in", "inc", "indeed", "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter", "latterly", "least", "less", "ltd", "made", "many", "may", "me", "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly", "move", "much", "must", "my", "myself", "name", "namely", "neither", "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone", "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on", "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our", "ours", "ourselves", "out", "over", "own","part", "per", "perhaps", "please", "put", "rather", "re", "same", "see", "seem", "seemed", "seeming", "seems", "serious", "several", "she", "should", "show", "side", "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone", "something", "sometime", "sometimes", "somewhere", "still", "such", "system", "take", "ten", "than", "that", "the", "their", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "therefore", "therein", "thereupon", "these", "they", "thick", "thin", "third", "this", "those", "though", "three", "through", "throughout", "thru", "thus", "to", "together", "too", "top", "toward", "towards", "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us", "very", "via", "was", "we", "well", "were", "what", "whatever", "when", "whence", "whenever", "where", "whereafter", "whereas", "whereby", "wherein", "whereupon", "wherever", "whether", "which", "while", "whither", "who", "whoever", "whole", "whom", "whose", "why", "will", "with", "within", "without", "would", "yet", "you", "your", "yours", "yourself", "yourselves", "the"]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfTransformer

# preprocessing all data
symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"

def removeStopWords(string):
    newstr = ""
    
    for word in string.split():
        if word not in stop_words and len(word)>1: 
            newstr = newstr+" "+word
    
    return newstr


for x in val['results']:
    if len(x)>4: 
        # lowercase
        x["title"] = np.char.lower(x["title"])
        x["description"] = np.char.lower(x["description"])
        
        # symbols
        for i in symbols:
            x["title"] = np.char.replace(x["title"], i, ' ')
            x["description"] = np.char.replace(x["description"], i, ' ')
        
        x["title"] = removeStopWords(str(x["title"]))
        x["description"] = removeStopWords(str(x["description"]))
        
            
        print(x["title"])
        print(x["description"])
# Out:
#  custom bitmoji teacher face covering
#  ❌❌⚠️⚠️please message photo like use wanting personalize name, leave notes seller using using black writing double check it’s spelled right ⚠️❌❌ personalize photo you, ready provide proofs purchasing happy send photo it’s finished lightweight extremely soft choice color elastic backing filter included layers fabric fabric inside 100 organic cotton fabric outside 84 polyester 16 spandex comfortable elastic ears pocket filter make warranties, express implied, mask prevents infection transmission viruses diseases medical grade comparable n95 covid19 accept returns cancellations item sales final
#  printable farm stickers farm envelope seals
#  description farm stickers envelope seals pdf, doc pdf word doc contain 20 5in stickers physical product shipped, frame props included what’s included you’ll receive file types quot 11 quot sheet 20 stickers, 300 dpi, high resolution, pdf format quot 11 quot sheet 20 stickers, word doc format payment cleared download instant download purchases reviews need download desktop computer able download mobile device printing process final project artwork determined quality printer paper card stock choose mind colors monitor vary slightly appear person display viewing device color calibration device monitor best results, recommend printing using high quality sticker paper note, listing instant download, print mailed print home, print shop, online service following vista print avery weprint recommend avery template 94506 refunds exchanges digital instant download purchase non refundable, way tell printed design questions concerns order, feel free reach anytime terms use purchase strictly non commercial, personal use print design home, business, public place resell, reproduce, distribute electronic means profit way design
#  handmade colourful indian embroidery notebooks, green purple yellow blue journals, manifestation diary 39
#  handmade notebooks threr beautiful handmade notebooks recycled materials contains handmade lokta paper colours available, contact photos colour pattern vary slightly size 20cm 15cm
#  princess personlized pillowcase, princess gift, girls pillowcase, custom pillowcase, personalized gifts, disney princesses pillowcase
#  ultra soft brushed microfiber allergies free 1800 thread count standard size 20 quot 30 quot pillowcase pillow included max printing size 14 quot 12 quot printed eco friendly water based inks soft smooth touch print felt pillowcase ensuring smooth feel face good nights sleep snuggle bed comfy pillowcase 39 super soft just perfect cozy night’s sleep work provide design proof won 39 print approval sure enter personalization information provided section listing production print pillowcase fresh order just usually able print order business days order printed shipped, usps usually delivers business days returns exchanges kindly note accept returns exchanges personalized custom items nature product custom orders final work orders order receive mind ordering gifts special occasions case larger special orders, immediately order materials needed produce order types orders canceled ex weddings, events, bulk custom orders, special items,
#  sterling silver lotus nose stud, tribal nose piercing, tiny indian nose jewelry, small rajasthani nostril screw, flower nose pin ns27
#  beautiful sterling silver lotus nose stud description material sterling silver gauge bar size 20 gauge 8mm total size 9mm 35 39 39 nickel free shipping business days need different gauge create custom order weeks create contact use septum correctly order taking care new septum, 39 important bend sides little possible putting clean septum brass silver oxidize naturally time contact skin wash bit lemon juice vinegar bring metal color, shining bright gold nose studs click link https etsy 33vw1dh nose studs click link https etsy 34im0ii enter shop https www etsy com il en shop ronibiza shop policies returns accepted guarantee refund entirely satisfied order like make return, contact 14 days receiving order thereafter, order shipped customer’s expense jewelry returned unworn original condition packaging ronibiza jewelry right deny return jewelry returned does meet return policy requirements customer responsible return shipping costs items lost damaged carefully inspect pieces leave studio item arrives damaged, reported immediately 24 hours lost damaged packages accept package integrity compromised shows clear signs having opened resealed note authority allowed open package transit local customs packages opened local customs sealed corresponding stamp company shipping orders shipped shipping address supplied etsy order check address correct completing checkout ronibiza jewelry responsible packages shipped incorrect addresses customer’s responsibility ensure shipping information correct prior complete purchase estimated shipping times international mail affected circumstances, 39 solve cases delays end period 30 days shipping date understand package sent, transit times, customs delays, delivery times totally control customs duties fees buyers responsible customs duties fees apply sellers aren 39 responsible delays customs issues postal services feel free contact questions regarding item, processing, shipping, arrival times happy help thank stopping roni
#  unicorn 39 red bull
#  quot listen don 39 listen me, listen brave passed roads long ago, red bull ran close covered footprints listen listen, listen quickly quot butterfly brave, tame smaller version peter beagle 39 red bull mythfit polyester fleece button eyes sand feet help stand nicely feather boa fiery mane tail adjustable approximately 14 inches tail tip horn tip inches tall
#  i05 135 meal icon stickers
#  meal planning stickers printed matte, white sticker paper die cut stickers non removable sheet perfect use planners erin condren, plum paper, filofax, kikki k, item order follow owlplanwithyou instagram updates sales artwork nedtidesigns
#  fmp 11 2pcs mink fur ball stud earring loop, 92 silver post, 18 colors blue
#  plating gold 16k electric gold plating silver original rhodium plating matte gold electric gold plating matte silver electric silver platingnumber 14 shape mink fur ball stud earring loop measuring approx 30 mm 30mm quot quantity pieces pair material genuine real mink fur, 8mm diameter raw brass unplated 925 sterling silver post 92 silver ear studs stoppers included 18 colors black, royal blue, brown, dark pink, yellow, purple lt pink, burgundy, fuchsia, navy, beige, violet sky blue, charcoal, gray, white, dark green, red wholesale 10pcs discount 30pcs 10 discount 50pcs 15 discount 100pcs 20 discount 300pcs 25 discount choose colors, quantities write buyer 39 memo send mail
#  sweet dreams canvas calligraphy painting, bedroom kids room nursery wall art sign decor, night sky moon stars
#  acrylic canvas painting words quot sweet dreams quot written calligraphy cursive beautiful bedroom, kid 39 room, nursery choose canvas sizes 10 11 14 inches pictures quot 10 quot special requests, contact happy custom orders different quotes, fonts, colors
#  tyler, creator flower boy demo tapes personalized spotify apple music plexiglass poster table stand choose song
#  choose interface size wish order spotify apple size a5 size 14 8cm 21cm inch a4 size 21cm 29 7cm 11 inch choose song album want displayed acrylic decor poster printed transparent 1,5mm plexiglass decors delivered small stands easily use table stand unique gift idea occasion responsibility safe delivery item feel free contact questions
#  soft blue medium rounded bowl
#  pretty, soft blue glaze brown stoneware, rounded shape bowl perfect size uses holding 12 oz, 39 great salad, yogurt, cereal, ice cream, snacks, chili favorite glaze combinations, favorite multi tasking vessel dimensions bowl quot high circumference quot holds 12 oz sierra pottery piece kind, attentive craftsmanship potter eileen sierra eastern coast sunshine state florida vessels hand thrown hand built using high quality stoneware oven microwave safe, glazed food safe functional glazes dishwasher safe, recommend hand washing damaged handled gently, just like ceramic pieces durable, functional stoneware wheel thrown hand built palm coast, fl, usa oven, microwave dishwasher safe recommend hand washing protect ceramic surface hand painted dipped, lead free, food safe glazes pieces ready shipped sent business days order placed joy finding homes pieces enjoyed family friends, pleasing eye functional
#  antler bottle opener
#  perfect gift outdoors person likes kick cold beverage handle red stag antler, new zealand relative elk opener chrome comfortable grip flare base ends sealed materials legally harvested repurposed
#  buffalo bone breastplate, ceremonial regalia, tone bone leather necklace, native inspired, pow wow jewelry
#  half size breastplate choker buffalo bone hairpipe turquoise beads pow wow ceremonial jewelry native american healing shaman inspired item ships using usps priority mail including insurance breastplate size 26 row choker breastplate quot high quot wide choker necklace 10 quot wide plus quot adjustable leather cords tie leather cord fringe quot long thanks visiting lennie 39 bead drawer click similar style ceremonial healing jewelry https www etsy com shop lenniesbeaddrawer search search query choker order date desc view type gallery ref shop search click return bone pendant choker section https www etsy com shop lenniesbeaddrawer section id 12381210 ref shopsection leftnav click return storefront https www etsy com shop lenniesbeaddrawer ref shopsection shophome leftnav
#  leonardo teenage mutant ninja turtles mini tmnt plush plushie toy
#  leonardo, leads, fluffy tiny teenage mutant ninja turtles embroidered face squishy shell non smoking, pet friendly home soft fleece, filled poly fiberfill rice weights legs wobbling
#  pc, rose wood applique onlay, shabby chic, wood carved home embellishments, furniture carving appliques suppliesrosette applique shabby
#  hello set pc flower rose wood applique supplies products unique designs decorate furniture, walls ceilings lightweight easily stick flat surface want i̇t better paint wax using cracks occur dry state good physical properties thanks stopping
#  mailing upgrade does shorten production turnaround time, shorten mailing transit time usps
#  buy item purchase items shop https www etsy com shop centimegift production time remains just upgrade mail type domestic shipping priority upgrade costs 4, shipping upgrade usps priority express upgrade costs 20, shipping upgrade ups days international shipping international express upgrade costs 35, shipping upgrade dhl international express
#  40 pcs nemesia strumosa danish flag flower seeds nemesia strumosa suttonii triumph national ensign fl420
#  40 pcs nemesia strumosa danish flag flower seeds nemesia strumosa suttonii triumph national ensign fl420 nemesia strumosa suttonii triumph national ensign charming cool season annual pretty little snapdragon shape flowers fragrant bloom wide range colours nemesia strumosa compact branched plant flowers early continues summer autumn perfect plant carpet bedding prefers moist drained soil needs sun day danish flag strain striking pansy like, deep flowers, compact habit ideal patio container compact bedding plant abundance showy flowers unquestionably powerfully impulsive flower colours recently introduction horticultural world petals blooded, strong vibrant red, clear contrast lower petals creamy whiteness making nemesia danish flag beautiful variety grow nemesia flower seed sow nemesia seeds indoors weeks frost sow flower seed surface starter compost gently firm compost, lightly cover soil damp wet exclude light nemesia seedlings large handle, transplant inch pots grow cooler conditions gradually acclimatize young nemesia seedlings outdoor conditions seedlings grow, pinch times encourage compact growth transplant outdoors risk frost passed, inches apart directly sow nemesia seeds outdoors prepared beds danger frost passed inches apart season annual usda zones height 10 inches bloom season late spring fall bloom color red environment sun soil type moist, drained, ph temperature 65 72 18 22 average germ time 14 days light required yes depth press seeds soil cover lightly sowing rate seeds plant moisture seeds moist germination plant spacing inches
#  golden ratio earrings, fibonacci sequence, golden mean, divine proportion, phi
#  golden ratio elegant round earrings dark wood symbol artists, architects, mathematicians naturalists, golden ratio depicts perfectly symmetrical relationship proportions appears patterns nature, including spiral arrangement plants shells, aesthetically pleasing basis design art architecture earring set finely hand painted gold enamel, 3mm wenge wood, non tarnish brass ear wires designs begin original hand drawing, cut laser cutter variety quality woods pieces finished cleaning, sanding necessary, sealed non toxic wood sealer
#  incense stick cone mango wood hole disc, eco friendly incense holder, incense burner ash catcher 20 free vegan friendly incense sticks
#  incense stick cone mango wood hole disc, natural, eco friendly bamboo incense holder incense burner ash catcher 20 free patchouli vegan friendly incense sticks details choose hole disk incense holder design comes 20 free incense sticks pick fragrance drop burn time incense stick hour double time branded incense including eco friendly mango wood holder approx diameter 9cm thickness 1cm holder hold incense sticks incense cone including vegan friendly incense sticks approx length 250mm holder incense sticks gift wrapped natural, eco friendly packaging shop announcement getting orders time aware likely delays estimated delivery times ongoing problems brought coronavirus pandemic thanks custom stay safe packaging bubble wrap envelopes plant based contain plastic free gifts orders £35gbp including shipping
#  love daddy, stamped vintage spoon, fathers day gift, gift
#  hand stamped vintage silver plate spoon special day stamped quot love daddy quot great gift wonderful daddy vintage piece lovingly hand stamped letter time create unique treasure that, impossible guarantee letters perfectly aligned believe lends charm piece tool markings silver plate, shown photos wonderful vintage pieces years prior use, imperfections expected treasured signs wear include minor plate loss, scratches, pitting hand washing highly recommended help preserve darkening letters darkening wear time, stamping impression remain
#  couples shirts like butt like beard shirts halloween couples matching funny costume tees
#  cool fun couples shirt combo enjoy wear halloween, work parties social gathering great halloween valentine 39 day sure choose correct design size drop options shirts 100 preshrunk cotton sizing chart listed jpeg picture item listing shirts unisex men 39 sizing care instructions best practice machine wash cold, inside hang dry
#  agust inspired gouache bts fanart bangtan sonyeondan 방탄소년단
#  print gouache painting newly release music video agust d2 min yoongi known suga print original artwork printed 300gsm paper, glossy finish inches 10x15cm inches 13x18cm select size drop menu
#  atv shirt mud shirt road shirt 4x4 shirt southern girl mudding shirt country shirt cute country shirt lifted truck
#  🌟🌟🌟important🌟🌟🌟 final day xmas orders december 🌟🌟🌟 pandemic intensity christmas, delays shipment orders 🌟🌟🌟 adult unisex tee retail fit 100 soft cotton unisex heavy tee classic fit 100 cotton check photos details processing time days holidays expect delays orders slightly higher usual, best order soon possible sizing unisex, runs true size graphic size chart recommend sizing feminine, fitted look material high quality adult unisex tee bella canvas unisex heavy tee gildan cotton shirts soft comfortable shipping time class shipping business days priority shipping includes tracking business days returns refund items order try best send products best quality problems caused us,we refund exchange 🌟🌟🌟if problem product, contact 🌟🌟🌟 🌟🌟🌟if questions request 🌟🌟🌟 thank
#  create air freshener aroma bead car freshie
#  create freshie shapes scents offer select shape fragrance want match needs air fresheners freshies highest quality aroma beads, oils fragrances allow days order ship include weekends holidays place freshie car, closet, drawer, office locker small space smelling fresh amazing freshies normally weeks fragrances longer time frame freshies aromatic warmer environments adding new scents note air fresheners handmade items, slight visual effect place freshie dashboard vehicle set plastic wood surfaces meant hang make sure like wick aroma facebook facebook com nowickaroma daily deals choose shape texas, cactus, flamingo, llama, unicorn head, tee pee, lips, mason jar, guitar, pineapple, heart, longhorn, cross, angel, cancer ribbon, mermaid tail, boot, palm tree, sunflower pina colada right choose scent scent name, scent color description thousand wishes bbw type light pink replica bath body works scent soft blend sparkling champagne, peonies almond crème bird paradise medium pink replica popular circle candle fragrance sweet tropical berries mingle aroma rich lotus blossoms vanilla orchid description scent definitely smells like circle candle car wash cherry red intense scent black cherries smells just like detailed car description scent smells like cherry strawberry leather cherry leather brown red sweet tart leathery scent blend leather intense scent black cherry description scent leather cherry mixed creed aventus replica highly luxurious cologne creed aventus base notes pineapple, bergamot, black currant apple, middle notes patchouli, dry birch, rose moroccan jasmine notes vanilla, musk oak moss description smells good greatly manly scent fierce brown replica abercrombie fierce notes fir, lemon orange rosemary, jasmine lily valley mid tones finishes musk, vetiver rosewood hawaiian flower light purple tropical blend fruity notes orange, pineapple, peach strawberry combined floral mixture jasmine lavender description scent smells like glade plug hawaiian breeze leather brown leathery bouquet smells like inside saddle shop love spell pink interpretation fragrance victoria’s secrets fresh fruity citrus fragrance notes grapefruit, apple, strawberries clementine’s middle note peach, black currant rose petals sweet white musky base note mahogany teakwood brown masculine luxurious scent fine woods blended light scents lavender geranium notes description scent smells just like bw candle monkey farts light orange unique blend bananas, fresh grapefruit, strawberries, kiwi, bubble gum touch vanilla pina colada yellow smells just like drink strawberry light pink sweet scent strawberry strawberry leather brown pink strawberry leather scent blend leather intense scent strawberry description scent leather strawberry mixed cherry leather sun tan lotion dark blue tropical twist coconut milk cool vanilla it’s perfect summer escape sweet saddle shop brown pink sweet leathery scent blend leather warmth vanilla musk wood description scent sweet leather mix leather bird paradise
#  jigsaw puzzle personalized baby gift toddler 1st birthday gift baby boy wooden puzzle dino toy baby girl gift infant
#  jigsaw puzzle personalized baby gift toddler 1st birthday gift baby boy wooden puzzle dino toy baby girl gift infant unique wooden toys little ones looking baby gifts amazing nursery decor puzzle meaningful personalized wooden toy helps develop motor skills baby serves wonderful decoration check store designs message custom ones great gift idea 1st birthday 2nd, 3rd christmas, thanksgiving, baby shower occasion baby girl, baby boy, toddlers kids notice don 39 mention design notes order dinosaurs design main photo subscribe newsletter special discounts, news offers http eepurl com g8gki5 add stands puzzle display decoration https www etsy com listing 782856542 acrylic stands puzzle ref listing published alert choose design listing multiple designs, check picture choose design want puzzle also, provide design 39 number quot add personalization quot box printed wood designs shop technology organic materials safe, non toxic paints used birch plywood board 31 inches 8mm letter 15 inches 4mm 36 inches tall 6cm gift packaging available checkout customize message request customization step choose correct letters baby 39 ex step decide want pegs text ex pegs, text back, pegs text step choose color scheme number option ex step provide design chose, text chose option quot add personalization quot box business days needed prepare send order custom designs little longer shipping time calculated package dispatched shipped date standard delivery rates usa 10 business days united kingdom 14 business days europe 16 business days canada business days countries business days

# %%
# calculate tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer

listing_str = []
for x in val['results']:
    if len(x)>4: 
        listing_str.append(str(x["title"]) + " " + str(x["description"]))

tfIdfVectorizer=TfidfVectorizer(use_idf=True)
tfIdf = tfIdfVectorizer.fit_transform(listing_str)
df = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF"])
df = df.sort_values('TF-IDF', ascending=False)
print (df)
# Out:
#                TF-IDF
# fabric       0.317357
# photo        0.281262
# personalize  0.211571
# filter       0.211571
# elastic      0.211571
# ...               ...
# favorite     0.000000
# fathers      0.000000
# farts        0.000000
# farm         0.000000
# 방탄소년단        0.000000
#
# [1432 rows x 1 columns]

# %%
print(df.iloc[0].name == "fabric")

for s in listing_str:
    tmpStr = []
    for w in s.split():
        for i in range(len(df)):
            if df.iloc[i].name==w:
                tmpStr.append( df.iloc[i] )
    s=tmpStr
    
print(listing_str)
print("hey")

# %%
print(listing_str)

# titles = x
# categories = y?
# no^
# # of items x vs. tf-idf for each

# K-NEAREST ALGO IMPLEMENTATION

import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

# %%
from sklearn.metrics import pairwise_distances_argmin
from collections import Counter, defaultdict
print("he")
